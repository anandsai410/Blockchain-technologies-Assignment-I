# %% [markdown]
# <a href="https://colab.research.google.com/github/anandsai410/Blockchain-technologies-Assignment-I/blob/main/ORT_Manual_Global_0104.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import datetime
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
nltk.download('punkt')
from nltk import punkt
import openpyxl
import pandas as pd
import numpy as np
import re
from datetime import datetime, date, time
import time
from dateutil.parser import parser
from dateutil.relativedelta import relativedelta
parser=parser()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# !pip install spark-nlp
# !pip install pyspark

import sparknlp
from sparknlp.annotator import DocumentAssembler, DateMatcher, MultiDateMatcher
from pyspark.sql.types import StringType
from pyspark.ml import Pipeline

spark = sparknlp.start()
spark
# Out:
# Requirement already satisfied: spark-nlp in /usr/local/lib/python3.10/dist-packages (5.3.2)
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Warning::Spark Session already created, some configs may not take.
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ce5cf5d36024:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = pd.read_excel("Global_0104_IP.xlsx")
df
# Out:
#                            Manager  \
# 0         Marie Hardiman (I322855)
# 1           Sourabh Shah (I033453)
# 2           Sourabh Shah (I033453)
# 3    Joanna Monette Alas (I316191)
# 4    Joanna Monette Alas (I316191)
# ..                             ...
# 447          Liam Hudson (I323795)
# 448          Liam Hudson (I323795)
# 449          Liam Hudson (I323795)
# 450       Gabor Szilagyi (I524140)
# 451       Gabor Szilagyi (I524140)
#
#                                          External Info          ORT manual  \
# 0    2024-03-28 20:24:55 - Aaron Cooke (I565751) (E... 2024-04-02 22:30:00
# 1    2024-04-01 15:48:55 - System (External Info)\n... 2024-04-02 14:01:26
# 2    2024-04-01 13:50:03 - Abhijith Menon (I554905)... 2024-04-02 14:00:50
# 3    2024-03-28 21:26:13 - Alfred Philip Esguerra (... 2024-04-05 04:31:00
# 4    2024-03-28 22:16:12 - Alfred Philip Esguerra (... 2024-04-04 04:30:00
# ..                                                 ...                 ...
# 447  2024-03-28 18:04:14 - Ciara Flynn (I529990) (E... 2024-04-01 05:29:56
# 448  2024-03-26 04:33:49 - Youssouf Sangare (I31938... 2024-04-14 05:29:56
# 449  2024-03-26 04:06:38 - Youssouf Sangare (I31938... 2024-04-06 04:06:12
# 450  2024-03-28 16:38:57 - Zsolt Papp (I574643) (Ex... 2024-04-08 19:30:00
# 451  2024-03-28 20:38:33 - Zsolt Papp (I574643) (Ex... 2024-04-08 19:30:00
#
#                           Assigned to            Number          State  \
# 0               Aaron Cooke (I565751)  CS20240007061863  Awaiting Info
# 1            Abhijith Menon (I554905)  CS20240007352683    In progress
# 2            Abhijith Menon (I554905)  CS20240007336198    In progress
# 3    Alfred Philip Esguerra (I562177)  CS20240007233684    In progress
# 4    Alfred Philip Esguerra (I562177)  CS20240007278267    In progress
# ..                                ...               ...            ...
# 447        Youssouf Sangare (I319380)  CS20240006832810    In progress
# 448        Youssouf Sangare (I319380)  CS20240007116737  Awaiting Info
# 449        Youssouf Sangare (I319380)  CS20240007147605    In progress
# 450              Zsolt Papp (I574643)  CS20240007339316  Awaiting Info
# 451              Zsolt Papp (I574643)  CS20240006903361    In progress
#
#        Priority   Next SLA due date Next SLA reason  \
# 0      2 - High 2024-04-02 22:30:00       ORT (SLA)
# 1      2 - High 2024-04-02 14:01:26       ORT (SLA)
# 2      2 - High 2024-04-02 14:00:50       ORT (SLA)
# 3      2 - High 2024-04-05 04:31:00       ORT (SLA)
# 4      2 - High 2024-04-04 04:30:00       ORT (SLA)
# ..          ...                 ...             ...
# 447  3 - Medium 2024-04-01 05:29:56       ORT (SLA)
# 448  3 - Medium 2024-04-14 05:29:56       ORT (SLA)
# 449  3 - Medium 2024-04-06 04:06:12       ORT (SLA)
# 450  3 - Medium 2024-04-08 19:30:00       ORT (SLA)
# 451  3 - Medium 2024-04-08 19:30:00       ORT (SLA)
#
#                                                   Tags Updated by  \
# 0                                                  NaN     system
# 1                                                  NaN     system
# 2                                                  NaN    I554905
# 3                                                  NaN     system
# 4                                                  NaN  INT_PB_SN
# ..                                                 ...        ...
# 447                          #Q1_2024_Backlog_Tracking     system
# 448                                                NaN     system
# 449                                                NaN     system
# 450                                                NaN     system
# 451  #PL_HELP, #PL_HELP_REVIEWED, #Q1_2024_Backlog_...     system
#
#                            Customer contact
# 0             Swapna Shetty S (S0021840755)
# 1       Prithvish Mruthunjaya (S0025128123)
# 2     SATS SF AMS SATS SF AMS (S0021762935)
# 3               Jeffrey Mauro (S0007760160)
# 4    Basavaraju Dharani Kumar (S0022079371)
# ..                                      ...
# 447           Michelle McCann (S0025036898)
# 448       Andrea Johnson-Hall (S0022315314)
# 449          Michael Schröder (S0019596017)
# 450               Marc Lübeck (S0020026715)
# 451             Meryem Caymaz (S0024607067)
#
# [452 rows x 12 columns]

# %%
ext_inf=df['External Info']
dte=df['ORT manual']
df['CP_ext_inf']=''
df['OA_ext_inf']=''
df['dates']=''
df['check']=''

# %%
pattern_SE = r'\>(.*?)\</p>'
pattern_OA = r'\<br/>(.*?)\<br/>'

for i in range(0,len(df)):
  xstr=""
  ystr=""
  x = re.findall(pattern_SE, df.iloc[i,1])
  y = re.findall(pattern_OA, df.iloc[i,1])
  for j in x:
     xstr = xstr+". "+str(j)
  for j in y:
     ystr = ystr+". "+str(j)
  df.iloc[i,12] = xstr
  df.iloc[i,13] = ystr

# %%
df
# Out:
#                            Manager  \
# 0         Marie Hardiman (I322855)
# 1           Sourabh Shah (I033453)
# 2           Sourabh Shah (I033453)
# 3    Joanna Monette Alas (I316191)
# 4    Joanna Monette Alas (I316191)
# ..                             ...
# 447          Liam Hudson (I323795)
# 448          Liam Hudson (I323795)
# 449          Liam Hudson (I323795)
# 450       Gabor Szilagyi (I524140)
# 451       Gabor Szilagyi (I524140)
#
#                                          External Info          ORT manual  \
# 0    2024-03-28 20:24:55 - Aaron Cooke (I565751) (E... 2024-04-02 22:30:00
# 1    2024-04-01 15:48:55 - System (External Info)\n... 2024-04-02 14:01:26
# 2    2024-04-01 13:50:03 - Abhijith Menon (I554905)... 2024-04-02 14:00:50
# 3    2024-03-28 21:26:13 - Alfred Philip Esguerra (... 2024-04-05 04:31:00
# 4    2024-03-28 22:16:12 - Alfred Philip Esguerra (... 2024-04-04 04:30:00
# ..                                                 ...                 ...
# 447  2024-03-28 18:04:14 - Ciara Flynn (I529990) (E... 2024-04-01 05:29:56
# 448  2024-03-26 04:33:49 - Youssouf Sangare (I31938... 2024-04-14 05:29:56
# 449  2024-03-26 04:06:38 - Youssouf Sangare (I31938... 2024-04-06 04:06:12
# 450  2024-03-28 16:38:57 - Zsolt Papp (I574643) (Ex... 2024-04-08 19:30:00
# 451  2024-03-28 20:38:33 - Zsolt Papp (I574643) (Ex... 2024-04-08 19:30:00
#
#                           Assigned to            Number          State  \
# 0               Aaron Cooke (I565751)  CS20240007061863  Awaiting Info
# 1            Abhijith Menon (I554905)  CS20240007352683    In progress
# 2            Abhijith Menon (I554905)  CS20240007336198    In progress
# 3    Alfred Philip Esguerra (I562177)  CS20240007233684    In progress
# 4    Alfred Philip Esguerra (I562177)  CS20240007278267    In progress
# ..                                ...               ...            ...
# 447        Youssouf Sangare (I319380)  CS20240006832810    In progress
# 448        Youssouf Sangare (I319380)  CS20240007116737  Awaiting Info
# 449        Youssouf Sangare (I319380)  CS20240007147605    In progress
# 450              Zsolt Papp (I574643)  CS20240007339316  Awaiting Info
# 451              Zsolt Papp (I574643)  CS20240006903361    In progress
#
#        Priority   Next SLA due date Next SLA reason  \
# 0      2 - High 2024-04-02 22:30:00       ORT (SLA)
# 1      2 - High 2024-04-02 14:01:26       ORT (SLA)
# 2      2 - High 2024-04-02 14:00:50       ORT (SLA)
# 3      2 - High 2024-04-05 04:31:00       ORT (SLA)
# 4      2 - High 2024-04-04 04:30:00       ORT (SLA)
# ..          ...                 ...             ...
# 447  3 - Medium 2024-04-01 05:29:56       ORT (SLA)
# 448  3 - Medium 2024-04-14 05:29:56       ORT (SLA)
# 449  3 - Medium 2024-04-06 04:06:12       ORT (SLA)
# 450  3 - Medium 2024-04-08 19:30:00       ORT (SLA)
# 451  3 - Medium 2024-04-08 19:30:00       ORT (SLA)
#
#                                                   Tags Updated by  \
# 0                                                  NaN     system
# 1                                                  NaN     system
# 2                                                  NaN    I554905
# 3                                                  NaN     system
# 4                                                  NaN  INT_PB_SN
# ..                                                 ...        ...
# 447                          #Q1_2024_Backlog_Tracking     system
# 448                                                NaN     system
# 449                                                NaN     system
# 450                                                NaN     system
# 451  #PL_HELP, #PL_HELP_REVIEWED, #Q1_2024_Backlog_...     system
#
#                            Customer contact  \
# 0             Swapna Shetty S (S0021840755)
# 1       Prithvish Mruthunjaya (S0025128123)
# 2     SATS SF AMS SATS SF AMS (S0021762935)
# 3               Jeffrey Mauro (S0007760160)
# 4    Basavaraju Dharani Kumar (S0022079371)
# ..                                      ...
# 447           Michelle McCann (S0025036898)
# 448       Andrea Johnson-Hall (S0022315314)
# 449          Michael Schröder (S0019596017)
# 450               Marc Lübeck (S0020026715)
# 451             Meryem Caymaz (S0024607067)
#
#                                             CP_ext_inf  \
# 0    . Hi there. Engineering and OPS investigation ...
# 1    . Hi Khushboo,. Thanks for joining the call, a...
# 2    . Thanks Wei, for the details you provided on ...
# 3    . Hi Jeffrey,<br /><br />Sorry to hear that th...
# 4    . Hi Basavaraju,<br /><br />Good day!<br /><br...
# ..                                                 ...
# 447  . <br/>Contact name: Michelle McCann<br/>Conta...
# 448  . Hi Andrea,. We are reviewing your feedback a...
# 449  . Hello Michael,. we are reviewing your feedba...
# 450  . Hello Marc,. Thank you for confirming these ...
# 451  . Dear Meryem,. Thank you for all the details ...
#
#                                             OA_ext_inf dates check
# 0    . You will receive an update about this incide...
# 1    . You will receive an update about this incide...
# 2    . You will receive an update about this incide...
# 3    . You will receive an update about this incide...
# 4    . You will receive an update about this incide...
# ..                                                 ...   ...   ...
# 447  . . Contact phone or email: +1-. . . Contact p...
# 448                                               . .
# 449
# 450
# 451
#
# [452 rows x 16 columns]

# %%
def is_date(string):
  if ((string[0:4]+string[5:7]+string[8:10]).isdigit()) or ((string[0:2]+string[3:5]+string[6:10]).isdigit()):
    return True
  else:
    return False

def convert_dte(x):
  if (x[0:2]+x[3:5]+x[6:10]).isdigit() and x[2]=="/" and int(x[0:2])<=12 and int(x[3:5])>12:
    y=datetime.strptime(x, "%m/%d/%Y")
    y=y.strftime("%Y.%m.%d")
    return y
  elif (x[0:2]+x[3:5]+x[6:10]).isdigit() and x[2]=="." and int(x[0:2])<=12 and int(x[3:5])>12:
    y=datetime.strptime(x, "%m.%d.%Y")
    y=y.strftime("%Y.%m.%d")
    return y
  elif (x[0:2]+x[3:5]+x[6:10]).isdigit() and x[2]=="-" and int(x[0:2])<=12 and int(x[3:5])>12:
    y=datetime.strptime(x, "%m-%d-%Y")
    y=y.strftime("%Y.%m.%d")
    return y
  elif (x[0:4]+x[5:7]+x[8:10]).isdigit() and x[4]=="-":
    y=datetime.strptime(x, "%Y-%m-%d")
    y=y.strftime("%Y.%m.%d")
    return y
  elif (x[0:2]+x[3:5]+x[6:10]).isdigit() and x[2]=="-":
    y=datetime.strptime(x, "%d-%m-%Y")
    y=y.strftime("%Y.%m.%d")
    return y
  elif (x[0:4]+x[5:7]+x[8:10]).isdigit() and x[4]==".":
    y=datetime.strptime(x, "%Y.%m.%d")
    y=y.strftime("%Y.%m.%d")
    return y
  elif (x[0:2]+x[3:5]+x[6:10]).isdigit() and x[2]==".":
    y=datetime.strptime(x, "%d.%m.%Y")
    y=y.strftime("%Y.%m.%d")
    return y
  elif (x[0:4]+x[5:7]+x[8:10]).isdigit() and x[4]=="/":
    y=datetime.strptime(x, "%Y/%m/%d")
    y=y.strftime("%Y.%m.%d")
    return y
  elif (x[0:2]+x[3:5]+x[6:10]).isdigit() and x[2]=="/":
    y=datetime.strptime(x, "%d/%m/%Y")
    y=y.strftime("%Y.%m.%d")
    return y
  else:
    return ''

# %%
# Step 1: Transforms raw texts to `document` annotation
document_assembler = (
    DocumentAssembler()
    .setInputCol("text")
    .setOutputCol("document")
)
# Step 2: Extracts one date information from text
date = (
    DateMatcher()
    .setInputCols("document") \
    .setOutputCol("date") \
    .setOutputFormat("yyyy.MM.dd")
)

pipl = Pipeline(stages=[document_assembler, date])

for i in range(0,len(df)):
  dtestr=""

  #ORT Assistant part
  text_oa = word_tokenize(df.iloc[i,13])
  for j in text_oa:
    if is_date(j):
      try:
        j=convert_dte(j)
      except (IndexError, ValueError):
        pass
      dtestr=dtestr+str(j)+","
#  df.iloc[i,14]+=dtestr+", "

  #Case Processor part
  text_cp = sent_tokenize(df.iloc[i,12])
  spark_df_cp = spark.createDataFrame(text_cp, StringType()).toDF("text")
  result_cp = pipl.fit(spark_df_cp).transform(spark_df_cp)
  resultdf_cp = result_cp.toPandas()
  for j in resultdf_cp['date']:
    if j != []:
      for k in j:
        dtestr=dtestr+str(k.result)+", "
  lst=[p.replace(" ","") for p in dtestr.split(",")]
  lst=list(set(lst))
  dtestr2=""
  for j in lst:
    if len(j)>5:
      dtestr2=dtestr2+j+","
  df.iloc[i,14]=dtestr2
  continue

# %%
df
# Out:
#                            Manager  \
# 0         Marie Hardiman (I322855)
# 1           Sourabh Shah (I033453)
# 2           Sourabh Shah (I033453)
# 3    Joanna Monette Alas (I316191)
# 4    Joanna Monette Alas (I316191)
# ..                             ...
# 447          Liam Hudson (I323795)
# 448          Liam Hudson (I323795)
# 449          Liam Hudson (I323795)
# 450       Gabor Szilagyi (I524140)
# 451       Gabor Szilagyi (I524140)
#
#                                          External Info          ORT manual  \
# 0    2024-03-28 20:24:55 - Aaron Cooke (I565751) (E... 2024-04-02 22:30:00
# 1    2024-04-01 15:48:55 - System (External Info)\n... 2024-04-02 14:01:26
# 2    2024-04-01 13:50:03 - Abhijith Menon (I554905)... 2024-04-02 14:00:50
# 3    2024-03-28 21:26:13 - Alfred Philip Esguerra (... 2024-04-05 04:31:00
# 4    2024-03-28 22:16:12 - Alfred Philip Esguerra (... 2024-04-04 04:30:00
# ..                                                 ...                 ...
# 447  2024-03-28 18:04:14 - Ciara Flynn (I529990) (E... 2024-04-01 05:29:56
# 448  2024-03-26 04:33:49 - Youssouf Sangare (I31938... 2024-04-14 05:29:56
# 449  2024-03-26 04:06:38 - Youssouf Sangare (I31938... 2024-04-06 04:06:12
# 450  2024-03-28 16:38:57 - Zsolt Papp (I574643) (Ex... 2024-04-08 19:30:00
# 451  2024-03-28 20:38:33 - Zsolt Papp (I574643) (Ex... 2024-04-08 19:30:00
#
#                           Assigned to            Number          State  \
# 0               Aaron Cooke (I565751)  CS20240007061863  Awaiting Info
# 1            Abhijith Menon (I554905)  CS20240007352683    In progress
# 2            Abhijith Menon (I554905)  CS20240007336198    In progress
# 3    Alfred Philip Esguerra (I562177)  CS20240007233684    In progress
# 4    Alfred Philip Esguerra (I562177)  CS20240007278267    In progress
# ..                                ...               ...            ...
# 447        Youssouf Sangare (I319380)  CS20240006832810    In progress
# 448        Youssouf Sangare (I319380)  CS20240007116737  Awaiting Info
# 449        Youssouf Sangare (I319380)  CS20240007147605    In progress
# 450              Zsolt Papp (I574643)  CS20240007339316  Awaiting Info
# 451              Zsolt Papp (I574643)  CS20240006903361    In progress
#
#        Priority   Next SLA due date Next SLA reason  \
# 0      2 - High 2024-04-02 22:30:00       ORT (SLA)
# 1      2 - High 2024-04-02 14:01:26       ORT (SLA)
# 2      2 - High 2024-04-02 14:00:50       ORT (SLA)
# 3      2 - High 2024-04-05 04:31:00       ORT (SLA)
# 4      2 - High 2024-04-04 04:30:00       ORT (SLA)
# ..          ...                 ...             ...
# 447  3 - Medium 2024-04-01 05:29:56       ORT (SLA)
# 448  3 - Medium 2024-04-14 05:29:56       ORT (SLA)
# 449  3 - Medium 2024-04-06 04:06:12       ORT (SLA)
# 450  3 - Medium 2024-04-08 19:30:00       ORT (SLA)
# 451  3 - Medium 2024-04-08 19:30:00       ORT (SLA)
#
#                                                   Tags Updated by  \
# 0                                                  NaN     system
# 1                                                  NaN     system
# 2                                                  NaN    I554905
# 3                                                  NaN     system
# 4                                                  NaN  INT_PB_SN
# ..                                                 ...        ...
# 447                          #Q1_2024_Backlog_Tracking     system
# 448                                                NaN     system
# 449                                                NaN     system
# 450                                                NaN     system
# 451  #PL_HELP, #PL_HELP_REVIEWED, #Q1_2024_Backlog_...     system
#
#                            Customer contact  \
# 0             Swapna Shetty S (S0021840755)
# 1       Prithvish Mruthunjaya (S0025128123)
# 2     SATS SF AMS SATS SF AMS (S0021762935)
# 3               Jeffrey Mauro (S0007760160)
# 4    Basavaraju Dharani Kumar (S0022079371)
# ..                                      ...
# 447           Michelle McCann (S0025036898)
# 448       Andrea Johnson-Hall (S0022315314)
# 449          Michael Schröder (S0019596017)
# 450               Marc Lübeck (S0020026715)
# 451             Meryem Caymaz (S0024607067)
#
#                                             CP_ext_inf  \
# 0    . Hi there. Engineering and OPS investigation ...
# 1    . Hi Khushboo,. Thanks for joining the call, a...
# 2    . Thanks Wei, for the details you provided on ...
# 3    . Hi Jeffrey,<br /><br />Sorry to hear that th...
# 4    . Hi Basavaraju,<br /><br />Good day!<br /><br...
# ..                                                 ...
# 447  . <br/>Contact name: Michelle McCann<br/>Conta...
# 448  . Hi Andrea,. We are reviewing your feedback a...
# 449  . Hello Michael,. we are reviewing your feedba...
# 450  . Hello Marc,. Thank you for confirming these ...
# 451  . Dear Meryem,. Thank you for all the details ...
#
#                                             OA_ext_inf  \
# 0    . You will receive an update about this incide...
# 1    . You will receive an update about this incide...
# 2    . You will receive an update about this incide...
# 3    . You will receive an update about this incide...
# 4    . You will receive an update about this incide...
# ..                                                 ...
# 447  . . Contact phone or email: +1-. . . Contact p...
# 448                                               . .
# 449
# 450
# 451
#
#                                                  dates check
# 0    2024.02.15,2024.03.15,2004.02.01,2024.01.12,20...
# 1                    2024.04.02,5319.01.01,2024.04.01,
# 2                    2024.04.01,2024.04.02,1692.01.05,
# 3                               2024.03.14,2024.03.13,
# 4                    2024.03.19,2024.03.20,2719.01.01,
# ..                                                 ...   ...
# 447                                        2024.01.01,
# 448
# 449                             5959.01.09,2017.07.25,
# 450                                        2024.04.08,
# 451                  2024.04.08,2024.04.01,2024.03.12,
#
# [452 rows x 16 columns]

# %%
for i in range(0,len(df)-1):
  omd = word_tokenize(str(df.iloc[i,2]))
  omdte = convert_dte(omd[0])
  if len(str(omdte))>5:
    for j in df.iloc[i,14].split(","):
      if str(omdte).replace(" ","")==str(j).replace(" ",""):
        df.iloc[i,15]='ORTM_OK'
        continue
      else:
        pass

# %%
count=0
for i in df.iloc[:,15]:
  if i=='ORTM_OK':
    count=count+1
print(count2)
# Out:
# 184

# %%
df
# Out:
#                            Manager  \
# 0         Marie Hardiman (I322855)
# 1           Sourabh Shah (I033453)
# 2           Sourabh Shah (I033453)
# 3    Joanna Monette Alas (I316191)
# 4    Joanna Monette Alas (I316191)
# ..                             ...
# 447          Liam Hudson (I323795)
# 448          Liam Hudson (I323795)
# 449          Liam Hudson (I323795)
# 450       Gabor Szilagyi (I524140)
# 451       Gabor Szilagyi (I524140)
#
#                                          External Info          ORT manual  \
# 0    2024-03-28 20:24:55 - Aaron Cooke (I565751) (E... 2024-04-02 22:30:00
# 1    2024-04-01 15:48:55 - System (External Info)\n... 2024-04-02 14:01:26
# 2    2024-04-01 13:50:03 - Abhijith Menon (I554905)... 2024-04-02 14:00:50
# 3    2024-03-28 21:26:13 - Alfred Philip Esguerra (... 2024-04-05 04:31:00
# 4    2024-03-28 22:16:12 - Alfred Philip Esguerra (... 2024-04-04 04:30:00
# ..                                                 ...                 ...
# 447  2024-03-28 18:04:14 - Ciara Flynn (I529990) (E... 2024-04-01 05:29:56
# 448  2024-03-26 04:33:49 - Youssouf Sangare (I31938... 2024-04-14 05:29:56
# 449  2024-03-26 04:06:38 - Youssouf Sangare (I31938... 2024-04-06 04:06:12
# 450  2024-03-28 16:38:57 - Zsolt Papp (I574643) (Ex... 2024-04-08 19:30:00
# 451  2024-03-28 20:38:33 - Zsolt Papp (I574643) (Ex... 2024-04-08 19:30:00
#
#                           Assigned to            Number          State  \
# 0               Aaron Cooke (I565751)  CS20240007061863  Awaiting Info
# 1            Abhijith Menon (I554905)  CS20240007352683    In progress
# 2            Abhijith Menon (I554905)  CS20240007336198    In progress
# 3    Alfred Philip Esguerra (I562177)  CS20240007233684    In progress
# 4    Alfred Philip Esguerra (I562177)  CS20240007278267    In progress
# ..                                ...               ...            ...
# 447        Youssouf Sangare (I319380)  CS20240006832810    In progress
# 448        Youssouf Sangare (I319380)  CS20240007116737  Awaiting Info
# 449        Youssouf Sangare (I319380)  CS20240007147605    In progress
# 450              Zsolt Papp (I574643)  CS20240007339316  Awaiting Info
# 451              Zsolt Papp (I574643)  CS20240006903361    In progress
#
#        Priority   Next SLA due date Next SLA reason  \
# 0      2 - High 2024-04-02 22:30:00       ORT (SLA)
# 1      2 - High 2024-04-02 14:01:26       ORT (SLA)
# 2      2 - High 2024-04-02 14:00:50       ORT (SLA)
# 3      2 - High 2024-04-05 04:31:00       ORT (SLA)
# 4      2 - High 2024-04-04 04:30:00       ORT (SLA)
# ..          ...                 ...             ...
# 447  3 - Medium 2024-04-01 05:29:56       ORT (SLA)
# 448  3 - Medium 2024-04-14 05:29:56       ORT (SLA)
# 449  3 - Medium 2024-04-06 04:06:12       ORT (SLA)
# 450  3 - Medium 2024-04-08 19:30:00       ORT (SLA)
# 451  3 - Medium 2024-04-08 19:30:00       ORT (SLA)
#
#                                                   Tags Updated by  \
# 0                                                  NaN     system
# 1                                                  NaN     system
# 2                                                  NaN    I554905
# 3                                                  NaN     system
# 4                                                  NaN  INT_PB_SN
# ..                                                 ...        ...
# 447                          #Q1_2024_Backlog_Tracking     system
# 448                                                NaN     system
# 449                                                NaN     system
# 450                                                NaN     system
# 451  #PL_HELP, #PL_HELP_REVIEWED, #Q1_2024_Backlog_...     system
#
#                            Customer contact  \
# 0             Swapna Shetty S (S0021840755)
# 1       Prithvish Mruthunjaya (S0025128123)
# 2     SATS SF AMS SATS SF AMS (S0021762935)
# 3               Jeffrey Mauro (S0007760160)
# 4    Basavaraju Dharani Kumar (S0022079371)
# ..                                      ...
# 447           Michelle McCann (S0025036898)
# 448       Andrea Johnson-Hall (S0022315314)
# 449          Michael Schröder (S0019596017)
# 450               Marc Lübeck (S0020026715)
# 451             Meryem Caymaz (S0024607067)
#
#                                             CP_ext_inf  \
# 0    . Hi there. Engineering and OPS investigation ...
# 1    . Hi Khushboo,. Thanks for joining the call, a...
# 2    . Thanks Wei, for the details you provided on ...
# 3    . Hi Jeffrey,<br /><br />Sorry to hear that th...
# 4    . Hi Basavaraju,<br /><br />Good day!<br /><br...
# ..                                                 ...
# 447  . <br/>Contact name: Michelle McCann<br/>Conta...
# 448  . Hi Andrea,. We are reviewing your feedback a...
# 449  . Hello Michael,. we are reviewing your feedba...
# 450  . Hello Marc,. Thank you for confirming these ...
# 451  . Dear Meryem,. Thank you for all the details ...
#
#                                             OA_ext_inf  \
# 0    . You will receive an update about this incide...
# 1    . You will receive an update about this incide...
# 2    . You will receive an update about this incide...
# 3    . You will receive an update about this incide...
# 4    . You will receive an update about this incide...
# ..                                                 ...
# 447  . . Contact phone or email: +1-. . . Contact p...
# 448                                               . .
# 449
# 450
# 451
#
#                                                  dates    check
# 0    2024.02.15,2024.03.15,2004.02.01,2024.01.12,20...  ORTM_OK
# 1                    2024.04.02,5319.01.01,2024.04.01,  ORTM_OK
# 2                    2024.04.01,2024.04.02,1692.01.05,  ORTM_OK
# 3                               2024.03.14,2024.03.13,
# 4                    2024.03.19,2024.03.20,2719.01.01,
# ..                                                 ...      ...
# 447                                        2024.01.01,
# 448
# 449                             5959.01.09,2017.07.25,
# 450                                        2024.04.08,  ORTM_OK
# 451                  2024.04.08,2024.04.01,2024.03.12,
#
# [452 rows x 16 columns]

# %%
import openpyxl
df.to_excel('Global_0104_OP', sheet_name='CHECK')
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1143                 try:
# -> 1144                     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1145                     if engine == "auto":
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     262     def __call__(self, *args, **kwds) -> T:
# --> 263         return self.__func__(*args, **kwds)
#     264
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in _get_option(pat, silent)
#     134 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 135     key = _get_single_key(pat, silent)
#     136
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in _get_single_key(pat, silent)
#     120             _warn_if_deprecated(pat)
# --> 121         raise OptionError(f"No such keys(s): {repr(pat)}")
#     122     if len(keys) > 1:
#
# OptionError: No such keys(s): 'io.excel..writer'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-590eebec76e1> in <cell line: 2>()
#       1 import openpyxl
# ----> 2 df.to_excel('Global_0104_OP', sheet_name='CHECK')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2372             inf_rep=inf_rep,
#    2373         )
# -> 2374         formatter.write(
#    2375             excel_writer,
#    2376             sheet_name=sheet_name,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     942             # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     943             # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 944             writer = ExcelWriter(  # type: ignore[abstract]
#     945                 writer, engine=engine, storage_options=storage_options
#     946             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1146                         engine = get_default_engine(ext, mode="writer")
#    1147                 except KeyError as err:
# -> 1148                     raise ValueError(f"No engine for filetype: '{ext}'") from err
#    1149
#    1150             if engine == "xlwt":
#
# ValueError: No engine for filetype: ''
